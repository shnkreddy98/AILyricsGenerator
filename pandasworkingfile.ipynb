# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/song_lyrics.csv")

# %%
df.head()
# Out:
#                title  tag     artist  year   views  \
# 0          Killa Cam  rap    Cam'ron  2004  173166
# 1         Can I Live  rap      JAY-Z  1996  468624
# 2  Forgive Me Father  rap   Fabolous  2003    4743
# 3       Down and Out  rap    Cam'ron  2004  144404
# 4             Fly In  rap  Lil Wayne  2005   78271
#
#                                        features  \
# 0                   {"Cam\\'ron","Opera Steve"}
# 1                                            {}
# 2                                            {}
# 3  {"Cam\\'ron","Kanye West","Syleena Johnson"}
# 4                                            {}
#
#                                               lyrics  id language_cld3  \
# 0  [Chorus: Opera Steve & Cam'ron]\nKilla Cam, Ki...   1            en
# 1  [Produced by Irv Gotti]\n\n[Intro]\nYeah, hah,...   3            en
# 2  Maybe cause I'm eatin\nAnd these bastards fien...   4            en
# 3  [Produced by Kanye West and Brian Miller]\n\n[...   5            en
# ...

# %%
df.tag.value_counts()
# Out:
# pop        2138587
# rap        1724816
# rock        793220
# rb          196462
# misc        181455
# country     100316
# Name: tag, dtype: int64

# %%
music = df[df!='misc']

# %%
music['language_cld3'] = music['language_cld3'].fillna(music['language_ft'])
music['language_cld3'] = music['language_cld3'].fillna(music['language'])

# %%
music.head()
# Out:
#                title  tag     artist  year   views  \
# 0          Killa Cam  rap    Cam'ron  2004  173166
# 1         Can I Live  rap      JAY-Z  1996  468624
# 2  Forgive Me Father  rap   Fabolous  2003    4743
# 3       Down and Out  rap    Cam'ron  2004  144404
# 4             Fly In  rap  Lil Wayne  2005   78271
#
#                                        features  \
# 0                   {"Cam\\'ron","Opera Steve"}
# 1                                            {}
# 2                                            {}
# 3  {"Cam\\'ron","Kanye West","Syleena Johnson"}
# 4                                            {}
#
#                                               lyrics  id language_cld3  \
# 0  [Chorus: Opera Steve & Cam'ron]\nKilla Cam, Ki...   1            en
# 1  [Produced by Irv Gotti]\n\n[Intro]\nYeah, hah,...   3            en
# 2  Maybe cause I'm eatin\nAnd these bastards fien...   4            en
# 3  [Produced by Kanye West and Brian Miller]\n\n[...   5            en
# ...

# %%
music.isna().sum()
# Out:
# title               165
# tag              181455
# artist                0
# year                  0
# views                 0
# features              0
# lyrics                0
# id                    0
# language_cld3     39817
# language_ft      134322
# language         226918
# dtype: int64

# %%
music.drop(['language_ft', 'language'], axis = 1, inplace = True)

# %%
music.dropna(subset = ['tag', 'language_cld3'], axis = 0, inplace = True)

# %%
music.shape
# Out:
# (4917290, 9)

# %%
music.isna().sum()
# Out:
# title            156
# tag                0
# artist             0
# year               0
# views              0
# features           0
# lyrics             0
# id                 0
# language_cld3      0
# dtype: int64

# %%
music.head()
# Out:
#                title  tag     artist  year   views  \
# 0          Killa Cam  rap    Cam'ron  2004  173166
# 1         Can I Live  rap      JAY-Z  1996  468624
# 2  Forgive Me Father  rap   Fabolous  2003    4743
# 3       Down and Out  rap    Cam'ron  2004  144404
# 4             Fly In  rap  Lil Wayne  2005   78271
#
#                                        features  \
# 0                   {"Cam\\'ron","Opera Steve"}
# 1                                            {}
# 2                                            {}
# 3  {"Cam\\'ron","Kanye West","Syleena Johnson"}
# 4                                            {}
#
#                                               lyrics  id language_cld3
# 0  [Chorus: Opera Steve & Cam'ron]\nKilla Cam, Ki...   1            en
# 1  [Produced by Irv Gotti]\n\n[Intro]\nYeah, hah,...   3            en
# 2  Maybe cause I'm eatin\nAnd these bastards fien...   4            en
# 3  [Produced by Kanye West and Brian Miller]\n\n[...   5            en
# ...

# %%
music['no_of_lines'] = music.lyrics.apply(lambda x: x.count("\n"))

# %%
music.head()
# Out:
#                title  tag     artist  year   views  \
# 0          Killa Cam  rap    Cam'ron  2004  173166
# 1         Can I Live  rap      JAY-Z  1996  468624
# 2  Forgive Me Father  rap   Fabolous  2003    4743
# 3       Down and Out  rap    Cam'ron  2004  144404
# 4             Fly In  rap  Lil Wayne  2005   78271
#
#                                        features  \
# 0                   {"Cam\\'ron","Opera Steve"}
# 1                                            {}
# 2                                            {}
# 3  {"Cam\\'ron","Kanye West","Syleena Johnson"}
# 4                                            {}
#
#                                               lyrics  id language_cld3  \
# 0  [Chorus: Opera Steve & Cam'ron]\nKilla Cam, Ki...   1            en
# 1  [Produced by Irv Gotti]\n\n[Intro]\nYeah, hah,...   3            en
# 2  Maybe cause I'm eatin\nAnd these bastards fien...   4            en
# 3  [Produced by Kanye West and Brian Miller]\n\n[...   5            en
# ...

# %%
music.lyrics = music.lyrics.apply(lambda x: x.replace("\n", " "))

# %%
music.head()
# Out:
#                title  tag     artist  year   views  \
# 0          Killa Cam  rap    Cam'ron  2004  173166
# 1         Can I Live  rap      JAY-Z  1996  468624
# 2  Forgive Me Father  rap   Fabolous  2003    4743
# 3       Down and Out  rap    Cam'ron  2004  144404
# 4             Fly In  rap  Lil Wayne  2005   78271
#
#                                        features  \
# 0                   {"Cam\\'ron","Opera Steve"}
# 1                                            {}
# 2                                            {}
# 3  {"Cam\\'ron","Kanye West","Syleena Johnson"}
# 4                                            {}
#
#                                               lyrics  id language_cld3  \
# 0  [Chorus: Opera Steve & Cam'ron] Killa Cam, Kil...   1            en
# 1  [Produced by Irv Gotti]  [Intro] Yeah, hah, ye...   3            en
# 2  Maybe cause I'm eatin And these bastards fiend...   4            en
# 3  [Produced by Kanye West and Brian Miller]  [In...   5            en
# ...

# %%
import re

def remove_text_inside_brackets(input_string):
    # Define a regular expression pattern for matching text inside square brackets
    pattern = re.compile(r'\[.*?\]')
    
    # Use sub() function to replace the matched pattern with an empty string
    result = re.sub(pattern, '', input_string)
    
    return result

# %%
music.to_csv('data/progress.csv')

# %%
music.lyrics = music.lyrics.apply(lambda x: remove_text_inside_brackets(x))

# %%
music.to_csv('data/progress.csv')

# %%
print(music.loc[music["id"] == 154314].values)
# Out:
# [['Do I Wanna Know?' 'rock' 'Arctic Monkeys' 2013 2965702 '{}'
# ...
